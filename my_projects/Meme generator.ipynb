# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
str = input("Enter the name of your text file: ");  

img = cv2.imread(str);
# Out:
# Enter the name of your text file:

# %%
# fixing the colors
RGB =  cv2.COLOR_BGR2RGB
plt.figure(figsize = (10,15))
img_rgb = cv2.cvtColor(img, RGB)

show_img(thresh_binary_inverted, "THRESH_BINARY_INVERTED")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-68-4a4b2d22c9a7> in <module>
#       2 RGB =  cv2.COLOR_BGR2RGB
#       3 plt.figure(figsize = (10,15))
# ----> 4 img_rgb = cv2.cvtColor(img, RGB)
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'CvtHelper'

# %%
plt.figure(figsize = (10,15))
print("Here is your image:")
plt.imshow(img_rgb);
# Out:
# Here is your image:

# %%
text_top = input("Enter the text for the TOP of the picture: ").upper();
# Out:
# Enter the text for the TOP of the picture: Guð er góður

# %%
text_bottom = input("Enter the text for the BOTTOM of the picture: ").upper()
# Out:
# Enter the text for the BOTTOM of the picture: image

# %%
from PIL import ImageFont, ImageDraw, Image

# %%
pil_im = Image.fromarray(img_rgb)
image = img_rgb.copy()

#  creating the draw
fontsize = 42
bordercolor = (0,0,0)
fillcolor = (255,255,255)
x_upper = 10
y_upper = 10

x_lower = 200
y_lower = 200

W, H = image.shape[0], image.shape[1]

draw = ImageDraw.Draw(pil_im)

w, h_top = draw.textsize(text_top)
w, h_bottom = draw.textsize(text_bottom)

font = ImageFont.truetype("../fonts/impact.ttf", fontsize)

w_top, w_bottom
# Out:
# (30, 30)

# %%
draw.text(((W-w)/2-5,(10)/2), text_top, font=font, fill=bordercolor)
draw.text(((W-w)/2+5,(10)/2), text_top, font=font, fill=bordercolor)
draw.text(((W-w)/2,(10-5)/2), text_top, font=font, fill=bordercolor)
draw.text(((W-w)/2,(10+5)/2), text_top, font=font, fill=bordercolor)


draw.text(((W-w)/2,(10)/2), text_top, font=font, fill=fillcolor)
#draw.text(((W-w)/2,(H-h)), text_bottom, font=font, fill=fillcolor)
#draw.text(((W-w)/2,(H-h)), text_top, font=font, fill=fillcolor)
#draw.text(((W-w)/2,(H-h)), text_bottom, font=font, fill=fillcolor)
#pil_im.save("output/hello.png", "PNG")

# loading the font, with the size

#draw.text((x_upper-5, y_upper), text_top, font=font, fill=bordercolor)
#draw.text((x_upper+5, y_upper), text_top, font=font, fill=bordercolor)
#draw.text((x_upper, y_upper-5), text_top, font=font, fill=bordercolor)
#draw.text((x_upper, y_upper+5), text_top, font=font, fill=bordercolor)

#draw.text((x_lower-5, y_lower), text_bottom, font=font, fill=bordercolor)
#draw.text((x_lower+5, y_lower), text_bottom, font=font, fill=bordercolor)
#draw.text((x_lower, y_lower-5), text_bottom, font=font, fill=bordercolor)
#draw.text((x_lower, y_lower+5), text_bottom, font=font, fill=bordercolor)

#draw.text((x_upper, y_upper), text_top, font=font, fill=fillcolor)
#draw.text((x_lower, y_lower), text_bottom, font=font, fill=fillcolor)

plt.figure(figsize = (10,15))
plt.imshow(pil_im)

# %%
overlay_image = np.copy(image)
